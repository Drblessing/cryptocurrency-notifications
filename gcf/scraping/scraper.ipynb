# %%
import json
import time

import pandas as pd
import requests
from bs4 import BeautifulSoup

with open('items.json') as f:
    items = json.load(f)

df = pd.DataFrame(items)
# remove duplicates
df = df.drop_duplicates(subset=['href_id'])

coins = requests.get("https://api.coingecko.com/api/v3/coins/list?include_platform=true").json()
coins = pd.DataFrame(coins)
# Rename id to api_id
coins = coins.rename(columns={'id': 'api_id'})
# Merge, coins and df on id, but leave out name
df = df.merge(coins[['api_id','symbol','platforms']], left_on='href_id', right_on='api_id', how='left')
# Get missing symbols
missing_symbols = df[df['symbol'].isna()]
href_ids = missing_symbols['href_id'].tolist()
href_urls = [f"https://www.coingecko.com/en/coins/{href_id}" for href_id in href_ids]

api_ids = []
for href_url in href_urls:
    try: 
        response = requests.get(href_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        # Find the api_id
        api_id = soup.find('span', string='API id')
        # Text is in next div
        api_id = api_id.find_next_sibling('div').text.strip()
        api_ids.append([api_id, href_url.split('/')[-1].strip()])
        time.sleep(3)

    except:
        print("ERROR")
        time.sleep(3)

# Create a dataframe from api_ids
api_ids = pd.DataFrame(api_ids, columns=['api_id', 'href_id'])
# Merge with coins
api_ids = api_ids.merge(coins[['api_id','symbol','platforms']], on='api_id', how='left')
# Merge with df rows missing symbols
mask = pd.isna(df['symbol'])
# Combine the two dataframes
df_merged = pd.merge(df[mask].dropna(axis=1), api_ids, on='href_id', how='left')
df_combined = pd.concat([df[~mask], df_merged])
df_combined.reset_index(drop=True, inplace=True)
# Turn platforms column into just the string of ethereum contract address
df_combined['platforms'] = df_combined['platforms'].apply(lambda x: x.get('ethereum'))
# Drop rows without ethereum contract
df_combined = df_combined.dropna(subset=['platforms'])
df_combined = df_combined[df_combined['platforms'] != '']
# Test that every platform is an ethereum address, i.e. a string that starts with 0x and is 42 characters long
assert df_combined['platforms'].apply(lambda x: x.startswith('0x') and len(x) == 42).all()

# Yay! 
# Now we have a dataframe with all the coins that gained and have an etherum contract address

# %%
import scraping
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import scraping
#
# ModuleNotFoundError: No module named 'scraping'

# %%
df_test
# Out:
#                  name            price  change                  href_id  \
# 1            Lido DAO            $2.47    7.9%                 lido-dao
# 5              Render            $1.33    5.9%             render-token
# 7           Chainlink            $7.64    5.7%                chainlink
# 9          Frax Share            $8.83    4.2%               frax-share
# 15            ApeCoin            $4.18    3.0%                  apecoin
# 18            Uniswap            $6.05    2.5%                  uniswap
# 22          Shiba Inu  $0.000010837354    2.4%                shiba-inu
# 23               Aave           $73.21    2.4%                     aave
# 24             Chiliz        $0.120544    2.4%                   chiliz
# 25        Rocket Pool           $43.95    2.3%              rocket-pool
# 30            GOLCOIN            $4.39  272.0%                  golcoin
# 34           UwU Lend           $13.42   24.9%                 uwu-lend
# 35   Gamma Strategies        $0.367599   24.4%         gamma-strategies
# 38          Presearch        $0.104915   23.8%                presearch
# 39               Zano            $1.02   21.9%                     zano
# 40               Blur        $0.641468   19.4%                     blur
# 42              Spell  $0.000838238676   19.0%              spell-token
# 43           Vita Inu  $0.000000014032   17.5%                 vita-inu
# 44                Tap  $0.007141769721   17.3%                      tap
# 46             Coin98        $0.300602   15.4%                   coin98
# 47               RSS3        $0.193753   15.2%                     rss3
# 48           TriasLab            $2.94   15.2%              trias-token
# 49                 0x        $0.266950   14.5%                       0x
# 50          LooksRare        $0.154655   13.6%                looksrare
# 53               X2Y2  $0.062388231771   11.9%                     x2y2
# 54           Red Kite        $0.122390   11.9%             polkafoundry
# 56            Coinweb  $0.020505544136   11.5%                  coinweb
# 57            Dimitra  $0.038557367025   11.2%                  dimitra
# 58             UniDex            $8.92   10.9%                   unidex
# 59               aelf        $0.325353    8.9%                     aelf
# 60        SSV Network           $38.21    7.9%              ssv-network
# 61            Telcoin  $0.002708183144    7.8%                  telcoin
# 62              ECOMI  $0.000762264944    7.6%                    ecomi
# 63        OriginTrail        $0.388733    7.5%              origintrail
# 64   Stargate Finance        $0.727126    7.3%         stargate-finance
# 67    Basic Attention        $0.266963    6.4%    basic-attention-token
# 68               COTI  $0.081224796207    6.2%                     coti
# 70          JasmyCoin  $0.005145495674    5.9%                jasmycoin
# 1             Toncoin            $2.26    7.5%                  toncoin
# 2   Synthetix Network            $2.51    3.5%  synthetix-network-token
# 5                 SXP        $0.644865   34.8%                      sxp
# 7                 OAX        $0.355253   23.9%                      oax
# 8       DSLA Protocol  $0.002478343260   19.3%            dsla-protocol
# 10       Ankr Network  $0.034197343293    5.5%             ankr-network
#
#                    api_id symbol                                   platforms
# 1                lido-dao    ldo  0x5a98fcbea516cf06857215779fd812ca3bef1b32
# 5            render-token   rndr  0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24
# 7               chainlink   link  0x514910771af9ca656af840dff83e8264ecf986ca
# 9              frax-share    fxs  0x3432b6a60d23ca0dfca7761b7ab56459d9c964d0
# 15                apecoin    ape  0x4d224452801aced8b2f0aebe155379bb5d594381
# 18                uniswap    uni  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984
# 22              shiba-inu   shib  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 23                   aave   aave  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9
# 24                 chiliz    chz  0x3506424f91fd33084466f402d5d97f05f8e3b4af
# 25            rocket-pool    rpl  0xd33526068d116ce69f19a9ee46f0bd304f21a51f
# 30                golcoin   golc  0x095797fd4297fb79883cc912a5ba6313b15c445d
# 34               uwu-lend    uwu  0x55c08ca52497e2f1534b59e2917bf524d4765257
# 35       gamma-strategies  gamma  0x6bea7cfef803d1e3d5f7c0103f7ded065644e197
# 38              presearch    pre  0xec213f83defb583af3a000b1c0ada660b1902a0f
# 39                   zano   zano  0xdb85f6685950e285b1e611037bebe5b34e2b7d78
# 40                   blur   blur  0x5283d291dbcf85356a21ba090e6db59121208b44
# 42            spell-token  spell  0x090185f2135308bad17527004364ebcc2d37e5f6
# 43               vita-inu   vinu  0xafcdd4f666c84fed1d8bd825aa762e3714f652c9
# 44                    tap    xtp  0x6368e1e18c4c419ddfc608a0bed1ccb87b9250fc
# 46                 coin98    c98  0xae12c5930881c53715b369cec7606b70d8eb229f
# 47                   rss3   rss3  0xc98d64da73a6616c42117b582e832812e7b8d57f
# 48            trias-token  trias  0x3a856d4effa670c54585a5d523e96513e148e95d
# 49                     0x    zrx  0xe41d2489571d322189246dafa5ebde1f4699f498
# 50              looksrare  looks  0xf4d2888d29d722226fafa5d9b24f9164c092421e
# 53                   x2y2   x2y2  0x1e4ede388cbc9f4b5c79681b7f94d36a11abebc9
# 54           polkafoundry    pkf  0x8b39b70e39aa811b69365398e0aace9bee238aeb
# 56                coinweb   cweb  0x505b5eda5e25a67e1c24a2bf1a527ed9eb88bf04
# 57                dimitra   dmtr  0x51cb253744189f11241becb29bedd3f1b5384fdb
# 58                 unidex  unidx  0x95b3497bbcccc46a8f45f5cf54b0878b39f8d96c
# 59                   aelf    elf  0xbf2179859fc6d5bee9bf9158632dc51678a4100e
# 60            ssv-network    ssv  0x9d65ff81a3c488d585bbfb0bfe3c7707c7917f54
# 61                telcoin    tel  0x467bccd9d29f223bce8043b84e8c8b282827790f
# 62                  ecomi    omi  0xed35af169af46a02ee13b9d79eb57d6d68c1749e
# 63            origintrail   trac  0xaa7a9ca87d3694b5755f213b5d04094b8d0f0a6f
# 64       stargate-finance    stg  0xaf5191b0de278c7286d6c7cc6ab6bb8a73ba2cd6
# 67  basic-attention-token    bat  0x0d8775f648430679a709e98d2b0cb6250d2887ef
# 68                   coti   coti  0xddb3422497e61e13543bea06989c0789117555c5
# 70              jasmycoin  jasmy  0x7420b4b9a0110cdc71fb720908340c03f9bc03ec
# 1        the-open-network    ton  0x582d872a1b094fc48f5de31d3b73f2d9be47def1
# 2                  havven    snx  0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f
# 5                   swipe    sxp  0x8ce9137d39326ad0cd6491fb5cc0cba0e089b6a9
# 7                 openanx    oax  0x701c244b988a513c945973defa05de933b23fe1d
# 8              stacktical   dsla  0x3affcca64c2a6f4e3b6bd9c64cd2c969efd1ecbe
# 10                   ankr   ankr  0x8290333cef9e6d528dd5618fb97a76f268f3edd4

# %%
df_combined.reset_index(drop=True, inplace=True)

# %%
# Drop rows where platforms is an empty string
assert df_test['platforms'].apply(lambda x: x.startswith('0x') and len(x) == 42).all()

# %%
assert false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 assert false
#
# NameError: name 'false' is not defined

# %%
coins[coins['api_id'] == 'xdce-crowd-sale']
# Out:
#                 api_id symbol         name         platforms
# 10684  xdce-crowd-sale    xdc  XDC Network  {'ethereum': ''}

# %%
missing_symbols = df[df['symbol'].isna()]

missing_symbols
# Scrape missing symbols from href_id

href_ids = missing_symbols['href_id'].tolist()
href_urls = [f"https://www.coingecko.com/en/coins/{href_id}" for href_id in href_ids]

# Send a request to each href_url and scrape the api_id every 5 second
import time
import requests
from bs4 import BeautifulSoup

api_ids = []
for href_url in href_urls:
    try: 
        response = requests.get(href_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        # Find the api_id
        api_id = soup.find('span', string='API id')
        # Text is in next div
        api_id = api_id.find_next_sibling('div').text.strip()
        api_ids.append([api_id, href_url.split('/')[-1]])
        time.sleep(3)

    except:
        print("ERROR")
        time.sleep(3)

# %%
# Create a dataframe from api_ids
api_ids = pd.DataFrame(api_ids, columns=['api_id', 'href_id'])
# Merge with coins
api_ids = api_ids.merge(coins[['api_id','symbol','platforms']], on='api_id', how='left')
# Merge with df rows missing symbols
mask = pd.isna(df['symbol'])

df_merged = pd.merge(df[mask].dropna(axis=1), api_ids, on='href_id', how='left')

# %%
df_combined = pd.concat([df[~mask], df_merged])

# %%
# Find all na values in df_combined
df_combined.isna().sum()
# Out:
# name         0
# price        0
# change       0
# href_id      0
# api_id       0
# symbol       0
# platforms    0
# dtype: int64

# %%
df_merged
# Out:
#                  name            price change                  href_id  \
# 0              Hedera  $0.073822899946  12.6%                   hedera
# 1             Toncoin            $2.26   7.5%                  toncoin
# 2   Synthetix Network            $2.51   3.5%  synthetix-network-token
# 3         XDC Network  $0.042008191359   2.7%              xdc-network
# 4             Conflux        $0.412902   2.1%                  conflux
# 5                 SXP        $0.644865  34.8%                      sxp
# 6                Nexa  $0.000020625638  24.3%                     nexa
# 7                 OAX        $0.355253  23.9%                      oax
# 8       DSLA Protocol  $0.002478343260  19.3%            dsla-protocol
# 9             Horizen           $11.01   6.1%                  horizen
# 10       Ankr Network  $0.034197343293   5.5%             ankr-network
#
#    api_id_x symbol_x platforms_x          api_id_y symbol_y  \
# 0       NaN      NaN         NaN  hedera-hashgraph     hbar
# 1       NaN      NaN         NaN  the-open-network      ton
# 2       NaN      NaN         NaN            havven      snx
# 3       NaN      NaN         NaN   xdce-crowd-sale      xdc
# 4       NaN      NaN         NaN     conflux-token      cfx
# 5       NaN      NaN         NaN             swipe      sxp
# 6       NaN      NaN         NaN          nexacoin     nexa
# 7       NaN      NaN         NaN           openanx      oax
# 8       NaN      NaN         NaN        stacktical     dsla
# 9       NaN      NaN         NaN           zencash      zen
# 10      NaN      NaN         NaN              ankr     ankr
#
#                                           platforms_y
# 0                                                  {}
# 1   {'ethereum': '0x582d872a1b094fc48f5de31d3b73f2...
# 2   {'ethereum': '0xc011a73ee8576fb46f5e1c5751ca3b...
# 3                                    {'ethereum': ''}
# 4                                                  {}
# 5   {'ethereum': '0x8ce9137d39326ad0cd6491fb5cc0cb...
# 6                                                  {}
# 7   {'ethereum': '0x701c244b988a513c945973defa05de...
# 8   {'ethereum': '0x3affcca64c2a6f4e3b6bd9c64cd2c9...
# 9                                                  {}
# 10  {'ethereum': '0x8290333cef9e6d528dd5618fb97a76...
